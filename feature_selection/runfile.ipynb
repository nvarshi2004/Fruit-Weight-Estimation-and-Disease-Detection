# %%
# %run Method1_Boruta.py
# Out:
# ...
# BORUTA FEATURE SELECTION & ML PIPELINE
# ...
#
# Please enter the path to your Excel file:
# File path:  C:\Users\varsh\Downloads\New folder (3)\final_feature_extraction.xlsx
# Please enter the output directory path:
# Output directory:  F:\dd\Results2
# ...
# LOADING DATA
# ...
# ✓ Data loaded successfully. Shape: (1843, 49)
#   Columns: ['Fruit', 'Weight', 'Contrast', 'Dissimilarity', 'Homogeneity', 'Energy', 'Correlation', 'Num_Pixels', 'Eccentricity', 'Extent', 'Solidity', 'Perimeter', 'Major_Axis', 'Minor_Axis', 'Equiv_Diameter', 'BBox_Area', 'H_Slice_1', 'H_Slice_2', 'H_Slice_3', 'H_Slice_4', 'H_Slice_5', 'H_Slice_6', 'H_Slice_7', 'H_Slice_8', 'H_Slice_9', 'H_Slice_10', 'V_Slice_1', 'V_Slice_2', 'V_Slice_3', 'V_Slice_4', 'V_Slice_5', 'V_Slice_6', 'V_Slice_7', 'V_Slice_8', 'V_Slice_9', 'V_Slice_10', 'DF_1', 'DF_2', 'DF_3', 'DF_4', 'DF_5', 'DF_6', 'DF_7', 'DF_8', 'DF_9', 'DF_10', 'DF_11', 'DF_12', 'DF_13']
#
# ...
# DATA CLEANING
# ...
# ✓ Data cleaning completed. Shape: (1843, 49)
#
# ✓ Data structure:
# ...

# %%
# %run Method2_RFE.py
# Out:
# ...
# RFE FEATURE SELECTION & ML PIPELINE
# ...
#
# Please enter the path to your Excel file:
# File path:  C:\Users\varsh\Downloads\final_feature_extraction.xlsx
# Please enter the output directory path:
# Output directory:  F:\dd\Results2
# ...
# LOADING DATA
# ...
# ✓ Data loaded successfully. Shape: (1843, 49)
#   Columns: ['Fruit', 'Weight', 'Contrast', 'Dissimilarity', 'Homogeneity', 'Energy', 'Correlation', 'Num_Pixels', 'Eccentricity', 'Extent', 'Solidity', 'Perimeter', 'Major_Axis', 'Minor_Axis', 'Equiv_Diameter', 'BBox_Area', 'H_Slice_1', 'H_Slice_2', 'H_Slice_3', 'H_Slice_4', 'H_Slice_5', 'H_Slice_6', 'H_Slice_7', 'H_Slice_8', 'H_Slice_9', 'H_Slice_10', 'V_Slice_1', 'V_Slice_2', 'V_Slice_3', 'V_Slice_4', 'V_Slice_5', 'V_Slice_6', 'V_Slice_7', 'V_Slice_8', 'V_Slice_9', 'V_Slice_10', 'DF_1', 'DF_2', 'DF_3', 'DF_4', 'DF_5', 'DF_6', 'DF_7', 'DF_8', 'DF_9', 'DF_10', 'DF_11', 'DF_12', 'DF_13']
#
# ...
# DATA CLEANING
# ...
# ✓ Data cleaning completed. Shape: (1843, 49)
#
# ✓ Data structure:
#   Sample IDs: Fruit
# ...

# %%
# %run Method3_SelectKBest.py
# Out:
# ...
# SELECTKBEST (F-TEST) FEATURE SELECTION & ML PIPELINE
# ...
#
# Please enter the path to your Excel file:
# File path:  C:\Users\varsh\Downloads\final_feature_extraction.xlsx
# Please enter the output directory path:
# Output directory:  F:\dd\Results2
# ...
# LOADING DATA
# ...
# ✓ Data loaded successfully. Shape: (1843, 49)
#   Columns: ['Fruit', 'Weight', 'Contrast', 'Dissimilarity', 'Homogeneity', 'Energy', 'Correlation', 'Num_Pixels', 'Eccentricity', 'Extent', 'Solidity', 'Perimeter', 'Major_Axis', 'Minor_Axis', 'Equiv_Diameter', 'BBox_Area', 'H_Slice_1', 'H_Slice_2', 'H_Slice_3', 'H_Slice_4', 'H_Slice_5', 'H_Slice_6', 'H_Slice_7', 'H_Slice_8', 'H_Slice_9', 'H_Slice_10', 'V_Slice_1', 'V_Slice_2', 'V_Slice_3', 'V_Slice_4', 'V_Slice_5', 'V_Slice_6', 'V_Slice_7', 'V_Slice_8', 'V_Slice_9', 'V_Slice_10', 'DF_1', 'DF_2', 'DF_3', 'DF_4', 'DF_5', 'DF_6', 'DF_7', 'DF_8', 'DF_9', 'DF_10', 'DF_11', 'DF_12', 'DF_13']
#
# ...
# DATA CLEANING
# ...
# ✓ Data cleaning completed. Shape: (1843, 49)
#
# ✓ Data structure:
# ...

# %%
# %run Method4_Lasso.py
# Out:
# ...
# LASSO L1 REGULARIZATION FEATURE SELECTION & ML PIPELINE
# ...
#
# Please enter the path to your Excel file:
# File path:  C:\Users\varsh\Downloads\final_feature_extraction1.xlsx
# Please enter the output directory path:
# Output directory:  F:\dd\Results2
# ...
# LOADING DATA
# ...
# ✓ Data loaded successfully. Shape: (1843, 49)
#   Columns: ['Fruit', 'Weight', 'Contrast', 'Dissimilarity', 'Homogeneity', 'Energy', 'Correlation', 'Num_Pixels', 'Eccentricity', 'Extent', 'Solidity', 'Perimeter', 'Major_Axis', 'Minor_Axis', 'Equiv_Diameter', 'BBox_Area', 'H_Slice_1', 'H_Slice_2', 'H_Slice_3', 'H_Slice_4', 'H_Slice_5', 'H_Slice_6', 'H_Slice_7', 'H_Slice_8', 'H_Slice_9', 'H_Slice_10', 'V_Slice_1', 'V_Slice_2', 'V_Slice_3', 'V_Slice_4', 'V_Slice_5', 'V_Slice_6', 'V_Slice_7', 'V_Slice_8', 'V_Slice_9', 'V_Slice_10', 'DF_1', 'DF_2', 'DF_3', 'DF_4', 'DF_5', 'DF_6', 'DF_7', 'DF_8', 'DF_9', 'DF_10', 'DF_11', 'DF_12', 'DF_13']
#
# ...
# DATA CLEANING
# ...
# ✓ Data cleaning completed. Shape: (1843, 49)
#
# ✓ Data structure:
# ...

# %%
# %run Method5_RF_Importance.py
# Out:
# ...
# RANDOM FOREST IMPORTANCE FEATURE SELECTION & ML PIPELINE
# ...
#
# Please enter the path to your Excel file:
# File path:  C:\Users\varsh\Downloads\New folder (3)\final_feature_extraction.xlsx
# Please enter the output directory path:
# Output directory:  F:\dd\Results2
# ...
# LOADING DATA
# ...
# ✓ Data loaded. Shape: (1843, 49)
#
# ...
# DATA CLEANING
# ...
# ✓ Data cleaning completed. Shape: (1843, 49)
#
# ✓ Data structure:
#   Target: Weight
#   Features: 47
#
# ...
# RANDOM FOREST FEATURE IMPORTANCE SELECTION
# ...
#
# Training Random Forest to calculate feature importances...
#
# Applying threshold for RF_Top80% (threshold=0.0074)...
# ✓ RF_Top80% completed: 37/47 features selected
#   Top 3 features: BBox_Area, Num_Pixels, Equiv_Diameter
#
# Applying threshold for RF_Top60% (threshold=0.0082)...
# ✓ RF_Top60% completed: 28/47 features selected
#   Top 3 features: BBox_Area, Num_Pixels, Equiv_Diameter
#
# Applying threshold for RF_AboveMean (threshold=0.0213)...
# ✓ RF_AboveMean completed: 5/47 features selected
# ...

# %%
# %run Master_Comparison.py
# Out:
# ...
# MASTER COMPARISON SCRIPT
# Comparing All Feature Selection Methods
# ...
#
# Please enter the base directory containing all method folders:
# (This should contain Method1_Boruta, Method2_RFE, etc.)
# Base directory:  F:\dd\Results2
# ...
# LOADING RESULTS FROM ALL METHODS
# ...
# ✓ Boruta: 54 results loaded
# ✓ RFE: 108 results loaded
# ✓ SelectKBest: 108 results loaded
# ✓ Lasso: 108 results loaded
# ✓ RF_Importance: 108 results loaded
#
# ✓ Total results combined: 486 rows
#
# ✓ Output directory: F:\dd\Results2\Master_Comparison
# ✓ Combined dataset saved: F:\dd\Results2\Master_Comparison\All_Methods_Combined.csv
#
# ...
# CREATING MASTER COMPARISON REPORT
# ...
# ✓ Master comparison visualization saved: F:\dd\Results2\Master_Comparison\Master_Comparison_Analysis.png
#
# Creating method ranking report...
# ✓ Method ranking report saved: F:\dd\Results2\Master_Comparison\Method_Ranking_Report.csv
#
# Creating top 20 configurations report...
# ...
